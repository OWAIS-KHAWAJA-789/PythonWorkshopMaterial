# %% [markdown]
# ### Workshop on Python for Mathematics and Statistics
# - Introduction to Python in Mathematics
# - Essential Python Libraries for mathematics & Statistics
# -  **The target of this session is**
# - - Linear Algebra
# - - - Vectors
# - - - - in 2D & 3D
# - - - Matrices
# - - - - Creation of and operation on matrix
# - - - Solving systems of equations
# - - Calculus
#
# - - - Functions
# - - - - How can we code a function and plot in python

# %% [markdown]
# # Vectors in 2D
# ### How to create a vector in python?

# %%
import numpy as np
import matplotlib.pyplot as plt
import arviz as az
import pandas as pd

# Generate simple vector
vector1 = np.array([2, 3])

# %% [markdown]
# #### Ploting the vector 1

# %%
vector1
plt.quiver(0, 0.6, vector1[0], vector1[1], angles='xy', scale_units='xy',color='b', scale=12)
# Set plot limits
plt.xlim(0, 1)
plt.ylim(0, 1)
# # Set axis labels
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# # Set grid and legend
plt.grid()
plt.show()

# %% [markdown]
# #### Exercise: How can we generate another vector using same code?

# %%
vector1 = np.array([2, 3])
vector2 = np.array([1, 4])
# Your code here?

# %% [markdown]
# #### Question: What about a vector in 3D?

# %%
vector1 = np.array([2,1,3])
# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
plt.quiver(1, 4,-1, vector1[0], vector1[1],vector1[2], color='r')
# Set plot limits
ax.set_xlim(-2,6)
ax.set_ylim(-2,3)
ax.set_zlim(-2,3)
# Set axis labels
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
# # Set grid and legend
ax.grid()
plt.show()

# %% [markdown]
# ### Exercise: how can we do this by changing the previous code?

# %%
vector1 = np.array([2,3,4])
vector2 = np.array([3,3,3])
# Your code here
#    ---------------------------
# Create a 3D plot

# Set plot limits

# Set axis labels

# # Set grid and legend

# %% [markdown]
# # Vector arithmitic
# - -  Vectors
# - - - Addition
# - - - Subtraction
# - - - Multiplication
# - - - - Dot
# - - - - Cross

# %%
np.cross(vector1,vector2)
# Out:
# array([ 21,   1, -15])

# %%
vector1-vector2
# Out:
# array([-1,  6, -1])

# %% [markdown]
# #### How can we check the addition of two vectors on plot?

# %%
vector1 = np.array([2, 2])
vector2 = np.array([5, 5])
vector3 =vector1+vector2
vector3
# Out:
# array([7, 7])

# %%
plt.quiver(0, 0, vector1[0], vector1[1], angles='xy', scale_units='xy', scale=15, color='r',label='V1')



# Set plot limits
plt.xlim(0, 1)
plt.ylim(0, 1)
# # Set axis labels
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# # Set grid and legend
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# #### Exercise: What about the subtraction here?

# %%
#  Do some changes to previouse code and get this plot

# %% [markdown]
# # Matrices
#
# ## Introduction:
#
# - Matrices are fundamental in linear algebra,
# - powerful tool to represent and solve systems of linear equations.
# - They find applications in various scientific and engineering fields, including data science, computer graphics, physics, and more.
# <br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How to create matrix in python
#
# - - <span style="color:blue">*what python libraries needed*?</span>
# - - <span style="color:blue">*what data structure we'll use*?</span>
# - - <span style="color:blue">*Operations*?</span>

# %% [markdown]
# ## Operations on matrices
#
# - - <span style="color:blue">*Addition*</span>
# - - <span style="color:blue">*Subtraction*</span>
# - - <span style="color:blue">*Multiplication*</span>

# %% [markdown]
# ## Operations on matrices
#
# - - <span style="color:blue">*Addition*</span>

# %%
li=[1,1,1,1,1,1]
A=np.array(li).reshape(3,2)
B=np.array(li).reshape(3,2)

# %%
A +B
# Out:
# array([[2, 2],
#        [2, 2],
#        [2, 2]])

# %%
A.shape
# Out:
# (3, 2)

# %% [markdown]
# ## Operations on matrices
#
# - - <span style="color:blue">*Subtraction*</span>

# %%
A
# Out:
# array([[1, 1],
#        [1, 1],
#        [1, 1]])

# %%
B
# Out:
# array([[1, 1],
#        [1, 1],
#        [1, 1]])

# %%
A-B
# Out:
# array([[0, 0],
#        [0, 0],
#        [0, 0]])

# %% [markdown]
# ## Operations on matrices
#
# - - <span style="color:blue">*Multiplication*</span>
#
#
# - - - A left Multiply B or A pre Multiply B
# - - - B right Multiply A or B post multiply A
# ![image.png](attachment:image.png)
#
# - Inner Dimention
# - outer Dimentions

# %% [markdown]
# ## Valid & invalide Matrix Multiplication
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Valid & invalide Matrix Multiplication
#
# ![image-3.png](attachment:image-3.png)
#
# ### <span style="color:Blue">What if we take transpose of A in second case?</span>

# %% [markdown]
# #### Valid & invalide Matrix Multiplication
# ![image.png](attachment:image.png)
# - <span style="color:Blue">transpose of A </span>

# %%
a= np.array([[4, 7],
             [2, 6]])

# %% [markdown]
# ## in matrices using python we can find
#
# - <span style="color:blue">Inverse</span>
# - <span style="color:blue">Determinant</span>
# - <span style="color:blue">Eigen values</span>
# - <span style="color:blue">etc</span>
#
# <span style="color:Red">[For More information on matrices click here](https://numpy.org/doc/stable/reference/routines.linalg.html)</span>

# %%
a= np.array([[2, 2],
             [2, 2]])

aa=np.linalg.inv(a)

# %%
det_value = np.linalg.det(a)

# %% [markdown]
# #### Using matrices, how can we solve system of linear equations using python
# - Lets do some examples via python
#
# ![image.png](attachment:image.png)

# %%
# creating matrix from this system
a=np.array([[1,1],[1,1]])
b=[-16,4]

# %%
# creating matrix from this system
a=np.array([[1,1],[1,1]])
b=[-16,4]

x=np.linalg.solve(a,b)
print(f'x={x[0]} and y = {x[1]}')

# %% [markdown]
# ### Exercise 1: Using matrices, how can we solve system of linear equations using python
#
# ![image.png](attachment:image.png)

# %%
# create matrices from above equation


# A  X = B
# then 
# use numpy to solve it and find the calue of x and y
# Out:
# x=3.0 and y = 4.0
# array([3., 4.])

# %% [markdown]
# #### Exercise 2: solve system of linear equations with 3 variables using python
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### lets explore some trignometric functions
# ![1_Poirej-MfmikrPbbtHo8uA.jpg](attachment:1_Poirej-MfmikrPbbtHo8uA.jpg)

# %%
xx = np.linspace(-np.pi,2*np.pi,50)

# %%
f = [0]*4
f
# Out:
# [0, 0, 0, 0]

# %%
# functions
f = [0]*2


#     function def       label
f[0] = np.sin(xx)     , 'sin(x)'
f[1] = np.cos(xx)     , 'cos(x)'


# f[1] = np.sin(xx)**2  , 'sin(x)**2'
# f[2] = np.sin(xx**2)  , 'sin(x**2)'
# f[3] = np.cos(xx)  , 'cos(xx)'

# %%
# and plot
for fun,label in f:
    
      plt.plot(xx,fun,linewidth=2,label=label)
plt.xlabel('Angle (rad.)')
plt.ylabel('y=f(x)')
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# #### Exercise : Use the same code change the function from sin to cos and analyse the plot

# %% [markdown]
# Thats the end of this session

# %% [markdown]
# #### What is the difference between inference and prediction?

# %% [markdown]
# - Inference: Drawing conclusions about a population from observed data.
# - Inference: Drawing conclusions about a population from observed data.

# %% [markdown]
# **Bayesian models update beliefs using Bayes' Theorem**
# ![12.jpg](attachment:12.jpg)

# %% [markdown]
# #### single paramter inference

# %% [markdown]
# - Prior: Initial belief about the probability distribution of a parameter before observing data.
#
#
# - Posterior: Updated belief about the probability distribution of a parameter after incorporating observed data

# %% [markdown]
# # synthetic data

# %%
# data = [1, 0, 0, 0, 1, 0, 1, 0, 0, 0]
import scipy.stats as stats
np.random.seed(123)
trials = 20
theta_real = 0.35  # unknown value in a real experiment
data = stats.bernoulli.rvs(p=theta_real, size=trials)
# data = stats.binom.rvs(n=1, p=theta_real, size=trials)

data

# %%
with pm.Model() as CFModel:
    # a priori
    θ = pm.Beta(name='θ', alpha=1., beta=1.)

    # likelihood
    y = pm.Binomial('y', p=θ, n=1, observed=data)
    trace = pm.sample(200)

# %% [markdown]
# ## Different prior information

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Posterior Distribution or updated belief of the model

# %%
trace.posterior['θ']

# %%
az.plot_trace(trace)

# %%
az.summary(trace)['mean']

# %% [markdown]
# #### Multiple paramter inference

# %%
ans = pd.read_csv('anscombe.csv')
x_3 = ans[ans.group == 'III']['x'].values
y_3 = ans[ans.group == 'III']['y'].values
x_3 = x_3 - x_3.mean()

# %%
plt.plot(x_3, y_3, 'C0o')
plt.xlabel('x')
plt.ylabel('y', rotation=0)
# Out:
# Text(0, 0.5, 'y')

# %%
az.plot_kde(y_3)
# Out:
# <Axes: >

# %%
with pm.Model() as model_t:
    α = pm.Normal('α', mu=y_3.mean(), sigma=1)
    β = pm.Normal('β', mu=0, sigma=1)
    ϵ = pm.HalfNormal('ϵ', 5)
    ν_ = pm.Exponential('ν_', 1/29)
    ν = pm.Deterministic('ν', ν_ + 1)

    y_pred = pm.StudentT('y_pred', mu=α + β * x_3, sigma=ϵ, nu=ν, observed=y_3)
    idata_t = pm.sample(2000, tune=2000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [α, β, ϵ, ν_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:13&lt;00:00 Sampling 2 chains, 0 divergences]
#     </div>
# ...

# %%
az.summary(idata_g)['mean'][:4]
# Out:
# α       7.502
# β       0.484
# ϵ       1.443
# μ[0]    7.987
# Name: mean, dtype: float64

# %%
with pm.Model() as model_g:
    α = pm.Normal('α', mu=0, sigma=10)
    β = pm.Normal('β', mu=0, sigma=1)
    ϵ = pm.HalfCauchy('ϵ', 5)
    μ = pm.Deterministic('μ', α + β * x_3)
   
    y_pred = pm.Normal('y_pred', mu=μ, sigma=ϵ, observed=y_3)

    idata_g = pm.sample(2000, tune=2000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [α, β, ϵ]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:06&lt;00:00 Sampling 2 chains, 0 divergences]
#     </div>
# ...

# %%
posterior_mean = az.extract(idata_g).mean()
plt.plot(x_3, y_3, 'C0o')
alpha_m = posterior_mean['α'].item()
beta_m = posterior_mean['β'].item()
plt.plot(x_3, alpha_m + beta_m * x_3, c='k', label='robust')

plt.xlabel('x')
plt.ylabel('y', rotation=0)
plt.legend(loc=2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
